# %% [markdown]
# # Creating your own dataset from Google Images
#
# *by: Francisco Ingham and Jeremy Howard. Inspired by [Adrian Rosebrock](https://www.pyimagesearch.com/2017/12/04/how-to-create-a-deep-learning-dataset-using-google-images/)*

# %% [markdown]
# In this tutorial we will see how to easily create an image dataset through Google Images. **Note**: You will have to repeat these steps for any new category you want to Google (e.g once for dogs and once for cats).

# %%
from fastai.vision import *

# %% [markdown]
# ## Get a list of URLs

# %% [markdown]
# ### Search and scroll

# %% [markdown]
# Go to [Google Images](http://images.google.com) and search for the images you are interested in. The more specific you are in your Google Search, the better the results and the less manual pruning you will have to do.
#
# Scroll down until you've seen all the images you want to download, or until you see a button that says 'Show more results'. All the images you scrolled past are now available to download. To get more, click on the button, and continue scrolling. The maximum number of images Google Images shows is 700.
#
# It is a good idea to put things you want to exclude into the search query, for instance if you are searching for the Eurasian wolf, "canis lupus lupus", it might be a good idea to exclude other variants:
#
#     "canis lupus lupus" -dog -arctos -familiaris -baileyi -occidentalis
#
# You can also limit your results to show only photos by clicking on Tools and selecting Photos from the Type dropdown.

# %% [markdown]
# ### Download into file

# %% [markdown]
# Now you must run some Javascript code in your browser which will save the URLs of all the images you want for you dataset.
#
# Press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>J</kbd> in Windows/Linux and <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>J</kbd> in Mac, and a small window the javascript 'Console' will appear. That is where you will paste the JavaScript commands.
#
# You will need to get the urls of each of the images. You can do this by running the following commands:
#
# ```javascript
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```

# %% [markdown]
# ### Create directory and upload urls file into your server

# %% [markdown]
# Choose an appropriate name for your labeled images. You can run these steps multiple times to create different labels.

# %%
folders = ['bajaj-avenger', 'bajaj-pulsar', 'ktm-duke', \
           'royal-enfield-classic', 'royal-enfield-thunderbird', \
           'yamaha-fz', 'yamaha-r15', 'other']
url_files = [f'{folder}-image-urls.txt' for folder in folders]

# %% [markdown]
# You will need to run this cell once per each category.

# %%
path = Path('../../data/indian-motorcycle-models')

# %%
for folder in folders:
    dest = path/folder
    dest.mkdir(parents=True, exist_ok=True)

# %%
path.ls()
# Out:
# [PosixPath('../../data/indian-motorcycle-models/other-motorcycle-model-image-urls.txt'),
#  PosixPath('../../data/indian-motorcycle-models/other-motorcycle'),
#  PosixPath('../../data/indian-motorcycle-models/bajaj-pulsar'),
#  PosixPath('../../data/indian-motorcycle-models/royal-enfield-thunderbird'),
#  PosixPath('../../data/indian-motorcycle-models/ktm-duke-image-urls.txt'),
#  PosixPath('../../data/indian-motorcycle-models/bajaj-avenger'),
#  PosixPath('../../data/indian-motorcycle-models/bajaj-avenger-image-urls.txt'),
#  PosixPath('../../data/indian-motorcycle-models/yamaha-r15-image-urls.txt'),
#  PosixPath('../../data/indian-motorcycle-models/royal-enfield-classic'),
#  PosixPath('../../data/indian-motorcycle-models/bajaj-pulsar-image-urls.txt'),
#  PosixPath('../../data/indian-motorcycle-models/royal-enfield-classic-image-urls.txt'),
#  PosixPath('../../data/indian-motorcycle-models/yamaha-fz'),
#  PosixPath('../../data/indian-motorcycle-models/yamaha-r15'),
#  PosixPath('../../data/indian-motorcycle-models/ktm-duke'),
#  PosixPath('../../data/indian-motorcycle-models/other-motorcycle-model'),
#  PosixPath('../../data/indian-motorcycle-models/royal-enfield-thunderbird-image-urls.txt'),
#  PosixPath('../../data/indian-motorcycle-models/yamaha-fz-image-urls.txt')]

# %% [markdown]
# Finally, upload your urls file. You just need to press 'Upload' in your working directory and select your file, then click 'Upload' for each of the displayed files.
#
# ![uploaded file](images/download_images/upload.png)

# %% [markdown]
# ## Download images

# %% [markdown]
# Now you will need to download your images from their respective urls.
#
# fast.ai has a function that allows you to do just that. You just have to specify the urls filename as well as the destination folder and this function will download and save all images that can be opened. If they have some problem in being opened, they will not be saved.
#
# Let's download our images! Notice you can choose a maximum number of images to be downloaded. In this case we will not download all the urls.
#
# You will need to run this line once for every category.

# %%
for idx, file in enumerate(url_files):
    download_images(path/file, path/folders[idx], max_pics=400)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 00:29<00:00]
#     </div>
# Error https://www.joyrideindia.com/wp-content/uploads/2015/09/Old-avenger.png HTTPSConnectionPool(host='www.joyrideindia.com', port=443): Max retries exceeded with url: /wp-content/uploads/2015/09/Old-avenger.png (Caused by SSLError(CertificateError("hostname 'www.joyrideindia.com' doesn't match either of 'joyrideindia.com.md-38.webhostbox.net', 'mail.joyrideindia.com.md-38.webhostbox.net', 'www.joyrideindia.com.md-38.webhostbox.net'",),))
# Error https://www.joyrideindia.com/wp-content/uploads/2016/05/Bajaj-Avenger-Street-150.png HTTPSConnectionPool(host='www.joyrideindia.com', port=443): Max retries exceeded with url: /wp-content/uploads/2016/05/Bajaj-Avenger-Street-150.png (Caused by SSLError(CertificateError("hostname 'www.joyrideindia.com' doesn't match either of 'joyrideindia.com.md-38.webhostbox.net', 'mail.joyrideindia.com.md-38.webhostbox.net', 'www.joyrideindia.com.md-38.webhostbox.net'",),))
# Error https://www.dpmco.com/public/images/product/avenger-220-cruise1.png HTTPSConnectionPool(host='www.dpmco.com', port=443): Max retries exceeded with url: /public/images/product/avenger-220-cruise1.png (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 00:22<00:00]
#     </div>
# Error https://www.joyrideindia.com/wp-content/uploads/2016/05/Bajaj-pulser-180-split-500x281.png HTTPSConnectionPool(host='www.joyrideindia.com', port=443): Max retries exceeded with url: /wp-content/uploads/2016/05/Bajaj-pulser-180-split-500x281.png (Caused by SSLError(CertificateError("hostname 'www.joyrideindia.com' doesn't match either of 'joyrideindia.com.md-38.webhostbox.net', 'mail.joyrideindia.com.md-38.webhostbox.net', 'www.joyrideindia.com.md-38.webhostbox.net'",),))
# Error https://topgear.wwmindia.com/photogallery/2018/sep/thumb_2013Apr04153312.jpg HTTPSConnectionPool(host='topgear.wwmindia.com', port=443): Read timed out. (read timeout=4)
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 00:31<00:00]
#     </div>
# Error https://www.icustommadeit.com/image/cache/data/incoming/images.icustommadeit.com/original/71/original-71769-500x500.jpg HTTPSConnectionPool(host='www.icustommadeit.com', port=443): Max retries exceeded with url: /image/cache/data/incoming/images.icustommadeit.com/original/71/original-71769-500x500.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 00:31<00:00]
#     </div>
# Error https://www.joyrideindia.com/wp-content/uploads/2016/05/classic500-500x281.png HTTPSConnectionPool(host='www.joyrideindia.com', port=443): Max retries exceeded with url: /wp-content/uploads/2016/05/classic500-500x281.png (Caused by SSLError(CertificateError("hostname 'www.joyrideindia.com' doesn't match either of 'joyrideindia.com.md-38.webhostbox.net', 'mail.joyrideindia.com.md-38.webhostbox.net', 'www.joyrideindia.com.md-38.webhostbox.net'",),))
# Error https://www.joyrideindia.com/wp-content/uploads/2016/05/classic_battle_green.png HTTPSConnectionPool(host='www.joyrideindia.com', port=443): Max retries exceeded with url: /wp-content/uploads/2016/05/classic_battle_green.png (Caused by SSLError(CertificateError("hostname 'www.joyrideindia.com' doesn't match either of 'joyrideindia.com.md-38.webhostbox.net', 'mail.joyrideindia.com.md-38.webhostbox.net', 'www.joyrideindia.com.md-38.webhostbox.net'",),))
# Error https://www.joyrideindia.com/wp-content/uploads/2015/09/Bullet-Classic-350-Split1-500x281.jpg HTTPSConnectionPool(host='www.joyrideindia.com', port=443): Max retries exceeded with url: /wp-content/uploads/2015/09/Bullet-Classic-350-Split1-500x281.jpg (Caused by SSLError(CertificateError("hostname 'www.joyrideindia.com' doesn't match either of 'joyrideindia.com.md-38.webhostbox.net', 'mail.joyrideindia.com.md-38.webhostbox.net', 'www.joyrideindia.com.md-38.webhostbox.net'",),))
# Error http://static-0.350cc.com/wp-content/uploads/2017/06/Royal-Enfield-Classic-Matte-Yellow-Paint-by-ParPin%E2%80%99s-Garage-1024x576.jpg HTTPConnectionPool(host='static-0.350cc.com', port=80): Max retries exceeded with url: /wp-content/uploads/2017/06/Royal-Enfield-Classic-Matte-Yellow-Paint-by-ParPin%E2%80%99s-Garage-1024x576.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f82cf544ba8>, 'Connection to static-0.350cc.com timed out. (connect timeout=4)'))
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 00:39<00:00]
#     </div>
# Error https://www.joyrideindia.com/wp-content/uploads/2016/05/Thunderbird-single-seat-500x281.png HTTPSConnectionPool(host='www.joyrideindia.com', port=443): Max retries exceeded with url: /wp-content/uploads/2016/05/Thunderbird-single-seat-500x281.png (Caused by SSLError(CertificateError("hostname 'www.joyrideindia.com' doesn't match either of 'joyrideindia.com.md-38.webhostbox.net', 'mail.joyrideindia.com.md-38.webhostbox.net', 'www.joyrideindia.com.md-38.webhostbox.net'",),))
# Error https://www.joyrideindia.com/wp-content/uploads/2016/05/Thunderbird-500-500x281.png HTTPSConnectionPool(host='www.joyrideindia.com', port=443): Max retries exceeded with url: /wp-content/uploads/2016/05/Thunderbird-500-500x281.png (Caused by SSLError(CertificateError("hostname 'www.joyrideindia.com' doesn't match either of 'joyrideindia.com.md-38.webhostbox.net', 'mail.joyrideindia.com.md-38.webhostbox.net', 'www.joyrideindia.com.md-38.webhostbox.net'",),))
# Error http://static-1.350cc.com/wp-content/gallery/Royal-Enfield-Thunderbird-cruiser-by-Jedi-Customs-Photo/Modified-Royal-Enfield-Thunderbied-painting.jpg HTTPConnectionPool(host='static-1.350cc.com', port=80): Max retries exceeded with url: /wp-content/gallery/Royal-Enfield-Thunderbird-cruiser-by-Jedi-Customs-Photo/Modified-Royal-Enfield-Thunderbied-painting.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f82cf4e6c50>, 'Connection to static-1.350cc.com timed out. (connect timeout=4)'))
# Error http://static-0.350cc.com/wp-content/gallery/Royal-Enfield-Thunderbird-cruiser-by-Jedi-Customs-Photo/Modified-Royal-Enfield-Thunderbied-Paint-Curiser.jpg HTTPConnectionPool(host='static-0.350cc.com', port=80): Max retries exceeded with url: /wp-content/gallery/Royal-Enfield-Thunderbird-cruiser-by-Jedi-Customs-Photo/Modified-Royal-Enfield-Thunderbied-Paint-Curiser.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPConnection object at 0x7f82cf5e1940>, 'Connection to static-0.350cc.com timed out. (connect timeout=4)'))
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 00:26<00:00]
#     </div>
# Error https://www.joyrideindia.com/wp-content/uploads/2016/04/FZ_single.png HTTPSConnectionPool(host='www.joyrideindia.com', port=443): Max retries exceeded with url: /wp-content/uploads/2016/04/FZ_single.png (Caused by SSLError(CertificateError("hostname 'www.joyrideindia.com' doesn't match either of 'joyrideindia.com.md-38.webhostbox.net', 'mail.joyrideindia.com.md-38.webhostbox.net', 'www.joyrideindia.com.md-38.webhostbox.net'",),))
# Error https://www.joyrideindia.com/wp-content/uploads/2016/04/FZ_single-500x281.png HTTPSConnectionPool(host='www.joyrideindia.com', port=443): Max retries exceeded with url: /wp-content/uploads/2016/04/FZ_single-500x281.png (Caused by SSLError(CertificateError("hostname 'www.joyrideindia.com' doesn't match either of 'joyrideindia.com.md-38.webhostbox.net', 'mail.joyrideindia.com.md-38.webhostbox.net', 'www.joyrideindia.com.md-38.webhostbox.net'",),))
# Error https://www.autopromag.com/wp-content/uploads/2018/01/2018-Yamaha-FZS-Fi-KTM-Duke-390.jpg HTTPSConnectionPool(host='www.autopromag.com', port=443): Max retries exceeded with url: /wp-content/uploads/2018/01/2018-Yamaha-FZS-Fi-KTM-Duke-390.jpg (Caused by ConnectTimeoutError(<urllib3.connection.VerifiedHTTPSConnection object at 0x7f82cf543be0>, 'Connection to www.autopromag.com timed out. (connect timeout=4)'))
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 00:25<00:00]
#     </div>
# Error https://www.yamaha-motor.co.nz/-/media/products/motorcycle/road/supersport/2016/yzf-r15g/gallery-and-videos-panel/yma_gallerypanel_1280x1024px_15_yzf-r15_4.ashx HTTPSConnectionPool(host='www.yamaha-motor.co.nz', port=443): Max retries exceeded with url: /-/media/products/motorcycle/road/supersport/2016/yzf-r15g/gallery-and-videos-panel/yma_gallerypanel_1280x1024px_15_yzf-r15_4.ashx (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 00:29<00:00]
#     </div>
# Error https://www.joyrideindia.com/wp-content/uploads/2015/09/splendor_pro-500x281.png HTTPSConnectionPool(host='www.joyrideindia.com', port=443): Max retries exceeded with url: /wp-content/uploads/2015/09/splendor_pro-500x281.png (Caused by SSLError(CertificateError("hostname 'www.joyrideindia.com' doesn't match either of 'joyrideindia.com.md-38.webhostbox.net', 'mail.joyrideindia.com.md-38.webhostbox.net', 'www.joyrideindia.com.md-38.webhostbox.net'",),))
# Error https://www.joyrideindia.com/wp-content/uploads/2015/09/splendor_pro.png HTTPSConnectionPool(host='www.joyrideindia.com', port=443): Max retries exceeded with url: /wp-content/uploads/2015/09/splendor_pro.png (Caused by SSLError(CertificateError("hostname 'www.joyrideindia.com' doesn't match either of 'joyrideindia.com.md-38.webhostbox.net', 'mail.joyrideindia.com.md-38.webhostbox.net', 'www.joyrideindia.com.md-38.webhostbox.net'",),))

# %%
# If you have problems download, try with `max_workers=0` to see exceptions:
download_images(path/file, dest, max_pics=20, max_workers=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# WantReadError                             Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     293         try:
# --> 294             return self.connection.recv_into(*args, **kwargs)
#     295         except OpenSSL.SSL.SysCallError as e:
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# ~/anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1613         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1614             raise WantReadError()
#    1615         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-90f92a041deb> in <module>
#       1 # If you have problems download, try with `max_workers=0` to see exceptions:
# ----> 2 download_images(path/file, dest, max_pics=20, max_workers=0)
#
# ~/fastai/fastai/vision/data.py in download_images(urls, dest, max_pics, max_workers, timeout)
#     194     dest = Path(dest)
#     195     dest.mkdir(exist_ok=True)
# --> 196     parallel(partial(_download_image_inner, dest, timeout=timeout), urls, max_workers=max_workers)
#     197
#     198 def resize_to(img, targ_sz:int, use_min:bool=False):
#
# ~/fastai/fastai/core.py in parallel(func, arr, max_workers)
#     299     "Call `func` on every element of `arr` in parallel using `max_workers`."
#     300     max_workers = ifnone(max_workers, defaults.cpus)
# --> 301     if max_workers<2: _ = [func(o,i) for i,o in enumerate(arr)]
#     302     else:
#     303         with ProcessPoolExecutor(max_workers=max_workers) as ex:
#
# ~/fastai/fastai/core.py in <listcomp>(.0)
#     299     "Call `func` on every element of `arr` in parallel using `max_workers`."
#     300     max_workers = ifnone(max_workers, defaults.cpus)
# --> 301     if max_workers<2: _ = [func(o,i) for i,o in enumerate(arr)]
#     302     else:
#     303         with ProcessPoolExecutor(max_workers=max_workers) as ex:
#
# ~/fastai/fastai/vision/data.py in _download_image_inner(dest, url, i, timeout)
#     187     suffix = re.findall(r'\.\w+?(?=(?:\?|$))', url)
#     188     suffix = suffix[0] if len(suffix)>0  else '.jpg'
# --> 189     download_image(url, dest/f"{i:08d}{suffix}", timeout=timeout)
#     190
#     191 def download_images(urls:Collection[str], dest:PathOrStr, max_pics:int=1000, max_workers:int=8, timeout=4):
#
# ~/fastai/fastai/vision/data.py in download_image(url, dest, timeout)
#     181
#     182 def download_image(url,dest, timeout=4):
# --> 183     try: r = download_url(url, dest, overwrite=True, show_progress=False, timeout=timeout)
#     184     except Exception as e: print(f"Error {url} {e}")
#     185
#
# ~/fastai/fastai/core.py in download_url(url, dest, overwrite, pbar, show_progress, chunk_size, timeout, retries)
#     164     s = requests.Session()
#     165     s.mount('http://',requests.adapters.HTTPAdapter(max_retries=retries))
# --> 166     u = s.get(url, stream=True, timeout=timeout)
#     167     try: file_size = int(u.headers["Content-Length"])
#     168     except: show_progress = False
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     544
#     545         kwargs.setdefault('allow_redirects', True)
# --> 546         return self.request('GET', url, **kwargs)
#     547
#     548     def options(self, url, **kwargs):
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     666
#     667         # Resolve redirects if allowed.
# --> 668         history = [resp for resp in gen] if allow_redirects else []
#     669
#     670         # Shuffle things around if there's history.
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in <listcomp>(.0)
#     666
#     667         # Resolve redirects if allowed.
# --> 668         history = [resp for resp in gen] if allow_redirects else []
#     669
#     670         # Shuffle things around if there's history.
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     245                     proxies=proxies,
#     246                     allow_redirects=False,
# --> 247                     **adapter_kwargs
#     248                 )
#     249
#
# ~/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# ~/anaconda3/lib/python3.7/http/client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# ~/anaconda3/lib/python3.7/http/client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# ~/anaconda3/lib/python3.7/http/client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# ~/anaconda3/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     304                 raise
#     305         except OpenSSL.SSL.WantReadError:
# --> 306             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     307                 raise timeout('The read operation timed out')
#     308             else:
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     141     Returns True if the socket is readable, or False if the timeout expired.
#     142     """
# --> 143     return wait_for_socket(sock, read=True, timeout=timeout)
#     144
#     145
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     102         return poll_obj.poll(t)
#     103
# --> 104     return bool(_retry_on_intr(do_poll, timeout))
#     105
#     106
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      40     # Modern Python, that retries syscalls by default
#      41     def _retry_on_intr(fn, timeout):
# ---> 42         return fn(timeout)
#      43 else:
#      44     # Old and broken Pythons.
#
# ~/anaconda3/lib/python3.7/site-packages/urllib3/util/wait.py in do_poll(t)
#     100         if t is not None:
#     101             t *= 1000
# --> 102         return poll_obj.poll(t)
#     103
#     104     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:

# %% [markdown]
# Then we can remove any images that can't be opened:

# %%
classes = ['bajaj-avenger', 'bajaj-pulsar', 'ktm-duke', \
           'royal-enfield-classic', 'royal-enfield-thunderbird', \
           'yamaha-fz', 'yamaha-r15', 'other']

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)
# Out:
# bajaj-avenger
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='381' class='' max='381', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [381/381 00:02<00:00]
#     </div>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/bajaj-avenger/00000325.jpg'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/bajaj-avenger/00000208.jpeg'>
# /home/paresh/anaconda3/lib/python3.6/site-packages/PIL/Image.py:916: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/bajaj-avenger/00000342.png'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/bajaj-avenger/00000067.png'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/bajaj-avenger/00000074.jpeg'>
# bajaj-pulsar
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='372' class='' max='372', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [372/372 00:02<00:00]
#     </div>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/bajaj-pulsar/00000125.png'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/bajaj-pulsar/00000275.png'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/bajaj-pulsar/00000300.jpeg'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/bajaj-pulsar/00000081.jpg'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/bajaj-pulsar/00000349.jpeg'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/bajaj-pulsar/00000084.png'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/bajaj-pulsar/00000144.jpeg'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/bajaj-pulsar/00000199.jpg'>
# /home/paresh/anaconda3/lib/python3.6/site-packages/PIL/Image.py:916: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# /home/paresh/anaconda3/lib/python3.6/site-packages/PIL/Image.py:916: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/bajaj-pulsar/00000175.png'>
# /home/paresh/anaconda3/lib/python3.6/site-packages/PIL/Image.py:916: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# /home/paresh/anaconda3/lib/python3.6/site-packages/PIL/Image.py:916: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/bajaj-pulsar/00000322.jpeg'>
# ktm-duke
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='394' class='' max='394', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [394/394 00:03<00:00]
#     </div>
# /home/paresh/anaconda3/lib/python3.6/site-packages/PIL/Image.py:916: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/ktm-duke/00000229.jpeg'>
# /home/paresh/anaconda3/lib/python3.6/site-packages/PIL/Image.py:916: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/ktm-duke/00000200.png'>
# /home/paresh/anaconda3/lib/python3.6/site-packages/PIL/Image.py:969: UserWarning: Couldn't allocate palette entry for transparency
#   "for transparency")
# int() argument must be a string, a bytes-like object or a number, not 'tuple'
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/ktm-duke/00000291.jpeg'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/ktm-duke/00000094.jpg'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/ktm-duke/00000214.jpg'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/ktm-duke/00000371.jpeg'>
# royal-enfield-classic
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='382' class='' max='382', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [382/382 00:02<00:00]
#     </div>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/royal-enfield-classic/00000319.jpeg'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/royal-enfield-classic/00000182.jpg'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/royal-enfield-classic/00000189.jpg'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/royal-enfield-classic/00000152.jpg'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/royal-enfield-classic/00000228.jpeg'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/royal-enfield-classic/00000190.jpeg'>
# royal-enfield-thunderbird
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='378' class='' max='378', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [378/378 00:03<00:00]
#     </div>
# /home/paresh/anaconda3/lib/python3.6/site-packages/PIL/Image.py:916: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/royal-enfield-thunderbird/00000154.jpeg'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/royal-enfield-thunderbird/00000339.jpeg'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/royal-enfield-thunderbird/00000332.jpg'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/royal-enfield-thunderbird/00000131.jpg'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/royal-enfield-thunderbird/00000376.jpeg'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/royal-enfield-thunderbird/00000158.jpg'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/royal-enfield-thunderbird/00000324.jpg'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/royal-enfield-thunderbird/00000214.jpeg'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/royal-enfield-thunderbird/00000129.jpg'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/royal-enfield-thunderbird/00000090.jpeg'>
# yamaha-fz
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='384' class='' max='384', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [384/384 00:03<00:00]
#     </div>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/yamaha-fz/00000071.jpg'>
# /home/paresh/anaconda3/lib/python3.6/site-packages/PIL/Image.py:916: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/yamaha-fz/00000362.jpg'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/yamaha-fz/00000318.png'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/yamaha-fz/00000226.jpg'>
# /home/paresh/anaconda3/lib/python3.6/site-packages/PIL/Image.py:916: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# /home/paresh/anaconda3/lib/python3.6/site-packages/PIL/Image.py:916: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/yamaha-fz/00000183.jpg'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/yamaha-fz/00000000.jpeg'>
# /home/paresh/anaconda3/lib/python3.6/site-packages/PIL/Image.py:916: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# /home/paresh/anaconda3/lib/python3.6/site-packages/PIL/Image.py:916: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# /home/paresh/anaconda3/lib/python3.6/site-packages/PIL/Image.py:916: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/yamaha-fz/00000343.jpg'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/yamaha-fz/00000168.jpg'>
# /home/paresh/anaconda3/lib/python3.6/site-packages/PIL/Image.py:916: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# yamaha-r15
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='385' class='' max='385', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [385/385 00:02<00:00]
#     </div>
# /home/paresh/anaconda3/lib/python3.6/site-packages/PIL/Image.py:916: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/yamaha-r15/00000181.jpg'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/yamaha-r15/00000294.jpg'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/yamaha-r15/00000358.jpg'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/yamaha-r15/00000116.jpg'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/yamaha-r15/00000176.jpg'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/yamaha-r15/00000331.jpg'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/yamaha-r15/00000236.jpg'>
# ../../data/indian-motorcycle-models/yamaha-r15/00000201.jpg: Removing corrupt EXIF data
# /home/paresh/anaconda3/lib/python3.6/site-packages/PIL/Image.py:916: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# other-motorcycle-model
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='386' class='' max='386', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [386/386 00:03<00:00]
#     </div>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/other-motorcycle-model/00000118.jpeg'>
# /home/paresh/anaconda3/lib/python3.6/site-packages/PIL/Image.py:916: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/other-motorcycle-model/00000166.jpg'>
# /home/paresh/anaconda3/lib/python3.6/site-packages/PIL/Image.py:916: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# /home/paresh/anaconda3/lib/python3.6/site-packages/PIL/Image.py:916: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# /home/paresh/anaconda3/lib/python3.6/site-packages/PIL/Image.py:916: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# /home/paresh/anaconda3/lib/python3.6/site-packages/PIL/Image.py:916: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/other-motorcycle-model/00000131.jpeg'>
# /home/paresh/anaconda3/lib/python3.6/site-packages/PIL/Image.py:916: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/other-motorcycle-model/00000224.jpg'>
# /home/paresh/anaconda3/lib/python3.6/site-packages/PIL/Image.py:916: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/other-motorcycle-model/00000028.jpg'>
# cannot identify image file <_io.BufferedReader name='../../data/indian-motorcycle-models/other-motorcycle-model/00000090.jpeg'>

# %% [markdown]
# ## View data

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
# If you already cleaned your data, run this cell instead of the one before
np.random.seed(42)
data = ImageDataBunch.from_csv("../../data/output", 
                               folder="../../data/indian-motorcycle-models", 
                               valid_pct=0.2, csv_labels='cleaned.csv', 
                               ds_tfms=get_transforms(), 
                               size=224, num_workers=4, bs=32
                              ).normalize(imagenet_stats)

# %% [markdown]
# Good! Let's take a look at some of our pictures then.

# %%
data.classes
# Out:
# ['bajaj-avenger',
#  'bajaj-pulsar',
#  'ktm-duke',
#  'other',
#  'royal-enfield-classic',
#  'royal-enfield-thunderbird',
#  'yamaha-fz',
#  'yamaha-r15']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['bajaj-avenger',
#   'bajaj-pulsar',
#   'ktm-duke',
#   'other',
#   'royal-enfield-classic',
#   'royal-enfield-thunderbird',
#   'yamaha-fz',
#   'yamaha-r15'],
#  8,
#  1923,
#  480)

# %% [markdown]
# ## Train model

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate, path='../../data/output')

# %%
learn.fit_one_cycle(5)
# Out:
# Total time: 01:27 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.974140</td>
#       <td>1.248974</td>
#       <td>0.422917</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.477268</td>
#       <td>1.093982</td>
#       <td>0.377083</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.207346</td>
#       <td>1.023431</td>
#       <td>0.327083</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.019128</td>
#       <td>0.960842</td>
#       <td>0.322917</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.892605</td>
#       <td>0.973099</td>
#       <td>0.316667</td>
#       <td>00:18</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.load('stage-1');

# %%
learn.fit_one_cycle(4, max_lr=slice(3e-5,3e-3))
# Out:
# Total time: 01:34 <p><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.874754</td>
#       <td>1.235639</td>
#       <td>0.327083</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.870094</td>
#       <td>0.947252</td>
#       <td>0.285417</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.551729</td>
#       <td>0.697306</td>
#       <td>0.216667</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.353631</td>
#       <td>0.652052</td>
#       <td>0.210417</td>
#       <td>00:23</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-2')

# %% [markdown]
# ## Interpretation

# %%
learn.load('stage-2');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix(figsize=(7, 7))

# %% [markdown]
# ## Cleaning Up
#
# Some of our top losses aren't due to bad performance by our model. There are images in our data set that shouldn't be.
#
# Using the `ImageCleaner` widget from `fastai.widgets` we can prune our top losses, removing photos that don't belong.

# %%
from fastai.widgets import *

# %% [markdown]
# First we need to get the file paths from our top_losses. We can do this with `.from_toplosses`. We then feed the top losses indexes and corresponding dataset to `ImageCleaner`.
#
# Notice that the widget will not delete images directly from disk but it will create a new csv file `cleaned.csv` from where you can create a new ImageDataBunch with the corrected labels to continue training your model.

# %%
path = Path('../../data/indian-motorcycle-models')

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn, ds_type=DatasetType.Valid)

# %%
ImageCleaner(ds, idxs, path)
# Out:
# HBox(children=(VBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00d\x00d\x00\x00\xff\xdb\x00C\x00\x02\x01\x01\x01\x01\x01\x02\x01\x01\x01\x02\x02\x02\x02\x02\x04\x03\x02\x02\x02\x02\x05\x04\x04\x03\x04\x06\x05\x06\x06\x06\x05\x06\x06\x06\x07\t\x08\x06\x07\t\x07\x06\x06\x08\x0b\x08\t\n\n\n\n\n\x06\x08\x0b\x0c\x0b\n\x0c\t\n\n\n\xff\xdb\x00C\x01\x02\x02\x02\x02\x02\x02\x05\x03\x03\x05\n\x07\x06\x07\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xff\xc0\x00\x11\x08\x01\xf4\x01M\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00\xcb\xa8\xa1\xff\x00]\xf8\xd3!\x9b\xf7\xb5r\x1f\xde\xd7\x18\x11\xcf\xda\xab\xf9>mX\x9a\x1a\xaf\x0c>L\xb8\xa0\x02k:\xaf5\x9djA\xde\x8f#\xde\xb4\x03\x1e\x18|\xaa<\xff\x00j\xd4\x9a\xce\xa3:<\x13V`S\xa8\xfc\xff\x00j\xb9yg\xe4\xd6t\xdf\xeb\xbf\x1a\x00\xbb\xfb\xef*\xaci\xba\x94\xfd*;;\xcb\x7f*\x8f\xdc\x7f\xaf\xfdh\x03c\xed\x9ew5$3V]\x9d\xe1\xf3kC\xce\x83\xf7t\x01r~\xd5\x1f\x9f\xedQ\xc37\x9bRO\xda\xb4\x00\x9ao*\xa4\x86j\xa7RY\xfe\xe7\xa5f\x04\x95%\x1f\xf2\xca\xab\xf9\xdf\xbd\xa0\x0b\xbfc\xb7\xf5?\x95E7\x9fRC7\xee\xaaJ\xcc\xd0\x8e\xce\x19\xfa\xd4s~\xea\xaeC4\x1d(\xbc\x86\xdeh\xa8\x03?\xfdmX\xb3\xa8\xe1\xb3\x9e\xacCg\xe4\xd0\x04\xb3\x7f\xa9\xfc+:\xb5&\x87\xf7U\x9f\xe4{\xd0\x04\x96sy?\xea*\xc7\x9d\xfb\xda\xa7\xe4{\xd4\x95\xce\x06\x84\x1d\xe8\x9a\x1a\x8e\xcf\xfdQ\xfaU\xcf\'\xf7U\xd0\x05xf\xa9*9\xa1\xfd\xedI\x0c5\xce\x04~\x7f\xb5I\x0e\xa7\xdf\x15\x1f\x91\xefQ\xf9\x1e\xf4\x01\xdc|+\xf1\xb4\xfe\x15\xf1m\xbd\xf4\x13\xfe\xef\xce\xaf\xd2O\xd9\xd7\xe2\x1c\x1e$\xd0m\xff\x00\x7f\xe6~\xe6\xbf)\xe1\x9a\xbe\xbc\xfd\x88\xbe2\xcf\xe5G\xa1\xcf}\xfb\xc8\xa8\x03\xefJ\xaf\xfb\x89\xaa\x9e\x8f\xa9\x7fiX\xc7<\x15\'\xef\xbc\xda\xe84#\x9a\xce\xb8\xef\x18\xf8;\xed\xda\x82\xcd\xe4\x8f\xbak\xb9\xff\x00[T\xef-|\xc9s@\x1f\x84\xf5$7\x93\xd4\x90w\xa2o"\xb49\xcb\x10\xcd\xe6\xd1T\xeaO\xb6{\xfe\x94\x01c\xcf\xf6\xab\x10\xcdY|M5\\\x83\xbd\x00X\x9f\xb5\x10\xcd\xe5QE\x00W\xbc\x86y\xab.\xf2\xcez\xd8\x9f\xb5W\xfd\xf7\x95@\x19pw\xab\x1e\x7f\xb5X\xf2=\xea?#\xde\x80\x08f\xa9<\xef\xde\xd4\x7f\xea\xaa\xc4\x1d\xe8\x02\xe5\x9djA\xde\xb1\xe1\xfd\xd5X\xfbd\xf0\x7f\xaf\xa0\x0b\x93y\x15$\x1d\xe8\xd3a\x9fX\x96;\x1b\x1b\x19.n%\xff\x00S\x140\xf9\x9emzE\x9f\xec\xeb\xaeh\xfa7\xfc%_\x15<U\xa2x\'K\xff\x00\x9e\xbe!\xbc\xf2\xa5\xff\x00\xbfUt\xa9V\xaa\x1e\xd7\xd8\x9e\x7f\xff\x00,\xaa\x9c\xd0\xfe\xf6\xaex\xc3\xf6\xa8\xff\x00\x82[|%\x97\xec>1\xfd\xa35/\x10^E\xfe\xba\x1f\x0fC\x14QW\x1f\xff\x00\x0fE\xff\x00\x82I\xf9\xbeG\xf6W\x8f\xff\x00\xeb\xb7\xdb"\xad>\xacg\xf5\x9a\'Q\xfe\xaa\xa4\x86j\x8f\xc1\xff\x00\xb5\xd7\xfc\x12\x87\xe2\xd4\xb1\xd8\xf8s\ ...
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %% [markdown]
# Flag photos for deletion by clicking 'Delete'. Then click 'Next Batch' to delete flagged photos and keep the rest in that row. `ImageCleaner` will show you a new row of images until there are no more to show. In this case, the widget will show you images until there are none left from `top_losses.ImageCleaner(ds, idxs)`

# %% [markdown]
# You can also find duplicates in your dataset and delete them! To do this, you need to run `.from_similars` to get the potential duplicates' ids and then run `ImageCleaner` with `duplicates=True`. The API works in a similar way as with misclassified images: just choose the ones you want to delete and click 'Next Batch' until there are no more images left.

# %%
ds, idxs = DatasetFormatter().from_similars(learn, ds_type=DatasetType.Valid)
# Out:
# Getting activations...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='38' class='' max='38', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [38/38 00:49<00:00]
#     </div>
# Computing similarities...

# %%
ImageCleaner(ds, idxs, path, duplicates=True)
# Out:
# HBox(children=(VBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x01\x00d\x00d\x00\x00\xff\xdb\x00C\x00\x02\x01\x01\x01\x01\x01\x02\x01\x01\x01\x02\x02\x02\x02\x02\x04\x03\x02\x02\x02\x02\x05\x04\x04\x03\x04\x06\x05\x06\x06\x06\x05\x06\x06\x06\x07\t\x08\x06\x07\t\x07\x06\x06\x08\x0b\x08\t\n\n\n\n\n\x06\x08\x0b\x0c\x0b\n\x0c\t\n\n\n\xff\xdb\x00C\x01\x02\x02\x02\x02\x02\x02\x05\x03\x03\x05\n\x07\x06\x07\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xff\xc0\x00\x11\x08\x015\x01\xcf\x03\x01"\x00\x02\x11\x01\x03\x11\x01\xff\xc4\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b\xff\xc4\x00\xb5\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142\x81\x91\xa1\x08#B\xb1\xc1\x15R\xd1\xf0$3br\x82\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz\t\n\x0b\xff\xc4\x00\xb5\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x02w\x00\x01\x02\x03\x11\x04\x05!1\x06\x12AQ\x07aq\x13"2\x81\x08\x14B\x91\xa1\xb1\xc1\t#3R\xf0\x15br\xd1\n\x16$4\xe1%\xf1\x17\x18\x19\x1a&\'()*56789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz?\x00\xfd\xfc\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a(\x00\xa2\x8a\xc6\xd6\xf5\xfd/@\xb0\xb9\xd5\xf5\xbdJ\xde\xd2\xd2\xd2\xdaI\xaenne\xf2\xe3\x81#\xe6I\x1d\xcf\xfa\xb4\xe2\x806h\xae{\xc0\xfe7\xf0\x7f\xc4\x7f\x0cY\xf8\xd7\xc0\x9e%\xb1\xd64mB/:\xc3R\xd3n\xa3\x9e\xde\xe2?\xf9\xe9\x1c\x91\xf5\xae\x86\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n(\xa2\x80\n\xfc\xb8\xff\x00\x82\xf3\x7f\xc1Y\xbe\x13~\xc8\xfe\x1d\xf0\xb7\xec\xc9\xaf\xf8F\x1f\x14?\x8d5\xeb\x7f\xf8K\xac\xa62y\x16\x9a\\rF\xf2o\xf2\xff\x00\xe5\xa7\x99\xe5\xc7\x1co\xf5\x93\xfd_\x97\'\xea\x14\x92\x88\x91\xe5\x97\xee\n\xf8\xab\xe3\x86\x83\xf0\x7fP\xff\x00\x82~\xf8\xaf\xc6?\x1a~\x16i\x1e-\x7f\x19\xc5\xa8^\xea\x96\xba\xdc1\xfd\x9d>\xdfq$q\xc9<\xf2\x7f\xc7\xbd\xbcq\xc9\x07\xef#\xfd\xe4q\xc7\xe6G@\x1e\xd3\xff\x00\x04\xfb\xf1\x16\x83\xe2\xcf\xd9C\xc2Z\xcf\x86\xe5w\xb6\x96\xd6O/\xcc\x97\x7f\xfc\xbcI\xf ...
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %% [markdown]
# Remember to recreate your ImageDataBunch from your `cleaned.csv` to include the changes you made in your data!

# %% [markdown]
# ## Putting your model in production

# %% [markdown]
# First thing first, let's export the content of our `Learner` object for production:

# %%
learn.export()

# %% [markdown]
# This will create a file named 'export.pkl' in the directory where we were working that contains everything we need to deploy our model (the model, the weights but also some metadata like the classes or the transforms/normalization used).

# %% [markdown]
# You probably want to use CPU for inference, except at massive scale (and you almost certainly don't need to train in real-time). If you don't have a GPU that happens automatically. You can test your model on CPU like so:

# %%
defaults.device = torch.device('cpu')

# %%
img = open_image(path/'bajaj-avenger'/'00000021.jpg')
img
# Out:
# Image (3, 445, 500)

# %% [markdown]
# We create our `Learner` in production enviromnent like this, jsut make sure that `path` contains the file 'export.pkl' from before.

# %%
learn = load_learner('../../data/output')

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# Category bajaj-avenger

# %% [markdown]
# So you might create a route something like this ([thanks](https://github.com/simonw/cougar-or-not) to Simon Willison for the structure of this code):
#
# ```python
# @app.route("/classify-url", methods=["GET"])
# async def classify_url(request):
#     bytes = await get_bytes(request.query_params["url"])
#     img = open_image(BytesIO(bytes))
#     _,_,losses = learner.predict(img)
#     return JSONResponse({
#         "predictions": sorted(
#             zip(cat_learner.data.classes, map(float, losses)),
#             key=lambda p: p[1],
#             reverse=True
#         )
#     })
# ```
#
# (This example is for the [Starlette](https://www.starlette.io/) web app toolkit.)

# %% [markdown]
# ## Things that can go wrong

# %% [markdown]
# - Most of the time things will train fine with the defaults
# - There's not much you really need to tune (despite what you've heard!)
# - Most likely are
#   - Learning rate
#   - Number of epochs

# %% [markdown]
# ### Learning rate (LR) too high

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(1, max_lr=0.5)
# Out:
# Total time: 00:13
# epoch  train_loss  valid_loss  error_rate
# 1      12.220007   1144188288.000000  0.765957    (00:13)

# %% [markdown]
# ### Learning rate (LR) too low

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %% [markdown]
# Previously we had this result:
#
# ```
# Total time: 00:57
# epoch  train_loss  valid_loss  error_rate
# 1      1.030236    0.179226    0.028369    (00:14)
# 2      0.561508    0.055464    0.014184    (00:13)
# 3      0.396103    0.053801    0.014184    (00:13)
# 4      0.316883    0.050197    0.021277    (00:15)
# ```

# %%
learn.fit_one_cycle(5, max_lr=1e-5)
# Out:
# Total time: 01:07
# epoch  train_loss  valid_loss  error_rate
# 1      1.349151    1.062807    0.609929    (00:13)
# 2      1.373262    1.045115    0.546099    (00:13)
# 3      1.346169    1.006288    0.468085    (00:13)
# 4      1.334486    0.978713    0.453901    (00:13)
# 5      1.320978    0.978108    0.446809    (00:13)

# %%
learn.recorder.plot_losses()

# %% [markdown]
# As well as taking a really long time, it's getting too many looks at each image, so may overfit.

# %% [markdown]
# ### Too few epochs

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate, pretrained=False)

# %%
learn.fit_one_cycle(1)
# Out:
# Total time: 00:14
# epoch  train_loss  valid_loss  error_rate
# 1      0.602823    0.119616    0.049645    (00:14)

# %% [markdown]
# ### Too many epochs

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.9, bs=32, 
        ds_tfms=get_transforms(do_flip=False, max_rotate=0, max_zoom=1, max_lighting=0, max_warp=0
                              ),size=224, num_workers=4).normalize(imagenet_stats)

# %%
learn = cnn_learner(data, models.resnet50, metrics=error_rate, ps=0, wd=0)
learn.unfreeze()

# %%
learn.fit_one_cycle(40, slice(1e-6,1e-4))
# Out:
# Total time: 06:39
# epoch  train_loss  valid_loss  error_rate
# 1      1.513021    1.041628    0.507326    (00:13)
# 2      1.290093    0.994758    0.443223    (00:09)
# 3      1.185764    0.936145    0.410256    (00:09)
# 4      1.117229    0.838402    0.322344    (00:09)
# 5      1.022635    0.734872    0.252747    (00:09)
# 6      0.951374    0.627288    0.192308    (00:10)
# 7      0.916111    0.558621    0.184982    (00:09)
# 8      0.839068    0.503755    0.177656    (00:09)
# 9      0.749610    0.433475    0.144689    (00:09)
# 10     0.678583    0.367560    0.124542    (00:09)
# 11     0.615280    0.327029    0.100733    (00:10)
# 12     0.558776    0.298989    0.095238    (00:09)
# 13     0.518109    0.266998    0.084249    (00:09)
# 14     0.476290    0.257858    0.084249    (00:09)
# 15     0.436865    0.227299    0.067766    (00:09)
# 16     0.457189    0.236593    0.078755    (00:10)
# 17     0.420905    0.240185    0.080586    (00:10)
# 18     0.395686    0.255465    0.082418    (00:09)
# 19     0.373232    0.263469    0.080586    (00:09)
# 20     0.348988    0.258300    0.080586    (00:10)
# 21     0.324616    0.261346    0.080586    (00:09)
# 22     0.311310    0.236431    0.071429    (00:09)
# 23     0.328342    0.245841    0.069597    (00:10)
# 24     0.306411    0.235111    0.064103    (00:10)
# 25     0.289134    0.227465    0.069597    (00:09)
# 26     0.284814    0.226022    0.064103    (00:09)
# 27     0.268398    0.222791    0.067766    (00:09)
# 28     0.255431    0.227751    0.073260    (00:10)
# 29     0.240742    0.235949    0.071429    (00:09)
# 30     0.227140    0.225221    0.075092    (00:09)
# 31     0.213877    0.214789    0.069597    (00:09)
# 32     0.201631    0.209382    0.062271    (00:10)
# 33     0.189988    0.210684    0.065934    (00:09)
# 34     0.181293    0.214666    0.073260    (00:09)
# 35     0.184095    0.222575    0.073260    (00:09)
# 36     0.194615    0.229198    0.076923    (00:10)
# 37     0.186165    0.218206    0.075092    (00:09)
# 38     0.176623    0.207198    0.062271    (00:10)
# 39     0.166854    0.207256    0.065934    (00:10)
# 40     0.162692    0.206044    0.062271    (00:09)

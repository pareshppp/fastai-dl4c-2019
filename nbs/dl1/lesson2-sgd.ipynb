# %%
# %matplotlib inline
from fastai.basics import *

# %% [markdown]
# In this part of the lecture we explain Stochastic Gradient Descent (SGD) which is an **optimization** method commonly used in neural networks. We will illustrate the concepts with concrete examples.

# %% [markdown]
# #  Linear Regression problem

# %% [markdown]
# The goal of linear regression is to fit a line to a set of points.

# %%
n=100

# %%
x = torch.ones(n,2) 
x[:,0].uniform_(-1.,1)
x[:5]
# Out:
# tensor([[ 0.8139,  1.0000],
#         [-0.0834,  1.0000],
#         [-0.0942,  1.0000],
#         [-0.8456,  1.0000],
#         [ 0.8379,  1.0000]])

# %%
a = tensor(3.,2); a
# Out:
# tensor([3., 2.])

# %%
y = x@a + torch.rand(n)

# %%
y.shape
# Out:
# torch.Size([100])

# %%
plt.scatter(x[:,0], y);

# %% [markdown]
# You want to find **parameters** (weights) `a` such that you minimize the *error* between the points and the line `x@a`. Note that here `a` is unknown. For a regression problem the most common *error function* or *loss function* is the **mean squared error**.

# %%
def mse(y_hat, y): return ((y_hat-y)**2).mean()

# %% [markdown]
# Suppose we believe `a = (-1.0,1.0)` then we can compute `y_hat` which is our *prediction* and then compute our error.

# %%
a = tensor(-1.,1)

# %%
y_hat = x@a
mse(y_hat, y)
# Out:
# tensor(7.3249)

# %%
plt.scatter(x[:,0],y)
plt.scatter(x[:,0],y_hat);

# %% [markdown]
# So far we have specified the *model* (linear regression) and the *evaluation criteria* (or *loss function*). Now we need to handle *optimization*; that is, how do we find the best values for `a`? How do we find the best *fitting* linear regression.

# %% [markdown]
# # Gradient Descent

# %% [markdown]
# We would like to find the values of `a` that minimize `mse_loss`.
#
# **Gradient descent** is an algorithm that minimizes functions. Given a function defined by a set of parameters, gradient descent starts with an initial set of parameter values and iteratively moves toward a set of parameter values that minimize the function. This iterative minimization is achieved by taking steps in the negative direction of the function gradient.
#
# Here is gradient descent implemented in [PyTorch](http://pytorch.org/).

# %%
a = nn.Parameter(a); a
# Out:
# Parameter containing:
# tensor([-1.,  1.], requires_grad=True)

# %%
def update():
    y_hat = x@a
    loss = mse(y, y_hat)
    if t % 10 == 0: print(loss)
    loss.backward()
    with torch.no_grad():
        a.sub_(lr * a.grad)
        a.grad.zero_()

# %%
lr = 1e-1
for t in range(100): update()
# Out:
# tensor(7.3249, grad_fn=<MeanBackward1>)
# tensor(1.3749, grad_fn=<MeanBackward1>)
# tensor(0.3820, grad_fn=<MeanBackward1>)
# tensor(0.1520, grad_fn=<MeanBackward1>)
# tensor(0.0977, grad_fn=<MeanBackward1>)
# tensor(0.0849, grad_fn=<MeanBackward1>)
# tensor(0.0818, grad_fn=<MeanBackward1>)
# tensor(0.0811, grad_fn=<MeanBackward1>)
# tensor(0.0809, grad_fn=<MeanBackward1>)
# tensor(0.0809, grad_fn=<MeanBackward1>)

# %%
plt.scatter(x[:,0],y)
plt.scatter(x[:,0],x@a);

# %% [markdown]
# ## Animate it!

# %%
from matplotlib import animation, rc
rc('animation', html='jshtml')

# %%
a = nn.Parameter(tensor(-1.,1))

fig = plt.figure()
plt.scatter(x[:,0], y, c='orange')
line, = plt.plot(x[:,0], x@a)
plt.close()

def animate(i):
    update()
    line.set_ydata(x@a)
    return line,

animation.FuncAnimation(fig, animate, np.arange(0, 100), interval=20)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img13ede6f411aa405abf543e91f344069b">
#     <br>
#     <input id="_anim_slider13ede6f411aa405abf543e91f344069b" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim13ede6f411aa405abf543e91f344069b.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim13ede6f411aa405abf543e91f344069b.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim13ede6f411aa405abf543e91f344069b.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim13ede6f411aa405abf543e91f344069b.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim13ede6f411aa405abf543e91f344069b.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim13ede6f411aa405abf543e91f344069b.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim13ede6f411aa405abf543e91f344069b.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim13ede6f411aa405abf543e91f344069b.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim13ede6f411aa405abf543e91f344069b.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim13ede6f411aa405abf543e91f344069b.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select13ede6f411aa405abf543e91f344069b" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img13ede6f411aa405abf543e91f344069b";
#     var slider_id = "_anim_slider13ede6f411aa405abf543e91f344069b";
#     var loop_select_id = "_anim_loop_select13ede6f411aa405abf543e91f344069b";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAAIABJREFUeJzt3X10VNX97/HPJAFsihZ5SCGiJCGA\
# QAwqw4NdVgEbFXyoSEQ0VYq2sb/6W7X21tpeV2vvvVJsb2tLlw+9uVrLTylUrUvWVYutRemvVhtH\
# wV/Raq0kCIgaEykoQkKy7x9jhjycM3Pm4cyZPfN+reXSnDlzzu6Qzoe99/fsHTLGGAEAYJmioBsA\
# AEAqCDAAgJUIMACAlQgwAICVCDAAgJUIMACAlQgwAICVCDAAgJUIMACAlQgwAICVCDAAgJUIMACA\
# lQgwAICVCDAAgJUIMACAlQgwAICVCDAAgJUIMACAlQgwAICVCDAAgJUIMACAlQgwAICVCDAAgJUI\
# MACAlQgwAICVCDAAgJUIMACAlQgwAICVCDAAgJUIMACAlQgwAICVCDAAgJUIMACAlQgwAICVSoJu\
# gF9Gjx6tioqKoJsBAFZpbW3Ve++9F3QzPMnbAKuoqFAkEgm6GQBglXA4HHQTPGMIEQBgJQIMAGAl\
# AgwAYCUCDABgJQIMAGAlAgwAbNeyVnqkQvp1UfTfLWuDblFW5G0ZPQAUhJa1UnOj1H0g+vOBHdGf\
# JamyIbh2ZQE9MACw2Us3HQmvXt0HosfzHAEGADY78GZyx/MIAQYANis9IbnjeYQAAwCbzVgpFZf2\
# P1ZcGj2e5wgwALBZZYM0u0kqnSApFP337Ka8L+CQqEIEAPtVNhREYA1EDwwAbMdzYAAA6/AcGADA\
# SjwHBgCwEs+BAQCsxHNgAAAr8RwYAMBKPAcGAPBdy9poccWBN6NDfDNWZiZoCvQ5MGsCrKKiQkcf\
# fbSKi4tVUlKiSCQSdJMAFIpMBE8Bl7v7xZoAk6SnnnpKo0ePDroZAApJpoInXrl7KmHoR0/OMsyB\
# AUA8bsHzwnXJXefADpfjSZa79wbqgR2SzJFALZDVN/qyJsBCoZDOPvtszZw5U01NTUE3B4DtvC6/\
# 5BYwne3eQ6NlraSQ82vJlrsX8IPLA1kzhPjMM8+ovLxc7777rurq6nTiiSfqjDPO6HdOU1NTLNza\
# 2tqCaCYAGyQzLFh6gnvvyevw30s3STIOL4SSL3cv4AeXB7KmB1ZeXi5JKisr0+LFi9Xc3DzonMbG\
# RkUiEUUiEY0ZMybbTQRgi2R6MfECxmtouJ5nkp+7KuAHlweyIsA+/PBD7d+/P/bfv//971VTUxNw\
# qwBYK5leTGWDNGSU8/leQ8M1dCZ4e39fBfzg8kBWBNg777yj008/XTNmzNDs2bN13nnn6dxzzw26\
# WQBslWwvJrw6vdBINXSc5ukK+MHlgayYA6uqqtJLL70UdDMA5IsZK/vPgUnxA6U3HFItXU/l/Ynm\
# 6QowsAYKGWOcZhatFw6HedgZgLtcf5bqkQrn4pHSCdJFrb7d1qbvTit6YACQcbnei6HaMCEr5sAA\
# IC1en/nK9D0fHC39OhT956HRyd2XasOECDAA+S2IlSta1krPrZC62o8c62yX/nqV9/tSbZgQAQYg\
# vwWxcsVLN0mma/Dxnk7v96XaMCHmwADkN9e5pB3R4UQ/ijfizVMlM4eV6/N0AaMHBiC/xZsz8ms4\
# Md49mcPKGAIMQH5zmkvqy4/hxBkrpdCQwceLhjKHlUEEGID81m8uyUWmS9MrG6S59/ZfgmroKGnO\
# LxkSzCDmwADkv965JNeHg30Y1mP+ynf0wAAUjkyXpgfxfBli6IEBKBzprmnYVzJ7isEXBBiAwpKp\
# ob14z5cRYFnBECIApIK1CgNHgAGAV33nvBRyPmfoyGy2qKAxhAgAXgyc85LLTlR5uUFVbqIHBgBe\
# OM15Oenq8L8tkESAAYA3Xue2WCoqawgwAIUrmee4vAQT251kFQEGoDC1rI3uz9V3n

# %% [markdown]
# In practice, we don't calculate on the whole file at once, but we use *mini-batches*.

# %% [markdown]
# ## Vocab

# %% [markdown]
# - Learning rate
# - Epoch
# - Minibatch
# - SGD
# - Model / Architecture
# - Parameters
# - Loss function
#
# For classification problems, we use *cross entropy loss*, also known as *negative log likelihood loss*. This penalizes incorrect confident predictions, and correct unconfident predictions.
